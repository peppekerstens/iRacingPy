# %%
$resultjson = get-content .\iracing_result\iracing-result-64291778.json
$result = $resultjson | ConvertFrom-Json

$race_result = $result.session_results.where{$_.simsession_name -like "RACE"}.results
$race_result
#$race_result.laps_complete
# Out:
# aggregate_champ_points     : 385
# ai                         : False
# average_lap                : 838684
# best_lap_num               : 33
# best_lap_time              : 811226
# best_nlaps_num             : -1
# best_nlaps_time            : -1
# best_qual_lap_at           : 1/1/1970 12:00:00 AM
# best_qual_lap_num          : -1
# best_qual_lap_time         : -1
# car_class_id               : 4029
# car_class_name             : GTP
# car_class_short_name       : GTP
# car_id                     : 168
# car_name                   : Cadillac V-Series.R GTP
# champ_points               : 350
# class_interval             : 0
# club_id                    : -1
# club_points                : 0
# display_name               : XBD Emiral Racing
# division                   : -1
# driver_results             : {@{aggregate_champ_points=350; ai=False; average_lap=832058;
#                              best_lap_num=33; best_lap_time=811226; best_nlaps_num=-1;
#                              best_nlaps_time=-1; best_qual_lap_at=1/1/1970 12:00:00 AM;
#                              best_qual_lap_num=-1; best_qual_lap_time=-1; car_class_id=4029;
#                              car_class_name=GTP; car_class_short_name=GTP; car_id=168;
#                              car_name=Cadillac V-Series.R GTP; champ_points=350; class_interval=0;
#                              club_id=24; club_name=Hispanoamérica; club_points=0;
#                              club_shortname=Hispanoamérica; cust_id=245246; display_name=Alberto
#                              García Blasco; division=-1; drop_race=False; finish_position=0;
#                              finish_position_in_class=0; friend=False; helmet=; incidents=3;
#                              interval=0; laps_complete=96; laps_lead=55; league_agg_points=350;
#                              league_points=350; license_change_oval=-1; license_change_road=-1;
#                              livery=; max_pct_fuel_fill=-1; multiplier=1; new_cpi=59.78842;
#                              new_license_level=19; new_sub_level=333; new_ttrating=1301;
#                              newi_rating=5901; old_cpi=59.78842; old_license_level=19;
#                              old_sub_level=333; old_ttrating=1301; oldi_rating=5901;
#                              opt_laps_complete=0; position=0; qual_lap_time=-1;
#                              reason_out=Running; reason_out_id=0; starting_position=0;
#                              starting_position_in_class=0; suit=; team_id=-306596; watched=False;
#                              weight_penalty_kg=-1}, @{aggregate_champ_points=350; ai=False;
#                              average_lap=833277; best_lap_num=113; best_lap_time=811230;
#                              best_nlaps_num=-1; best_nlaps_time=-1; best_qual_lap_at=1/1/1970
#                              12:00:00 AM; best_qual_lap_num=-1; best_qual_lap_time=-1;
#                              car_class_id=4029; car_class_name=GTP; car_class_short_name=GTP;
#                              car_id=168; car_name=Cadillac V-Series.R GTP; champ_points=350;
#                              class_interval=0; club_id=38; club_name=Iberia; club_points=0;
#                              club_shortname=Iberia; cust_id=410026; display_name=Pablo Álvarez;
#                              division=-1; drop_race=False; finish_position=0;
#                              finish_position_in_class=0; friend=False; helmet=; incidents=11;
#                              interval=0; laps_complete=76; laps_lead=67; league_agg_points=350;
#                              league_points=350; license_change_oval=-1; license_change_road=-1;
#                              livery=; max_pct_fuel_fill=-1; multiplier=1; new_cpi=59.890926;
#                              new_license_level=19; new_sub_level=333; new_ttrating=1350;
#                              newi_rating=4723; old_cpi=59.890926; old_license_level=19;
#                              old_sub_level=333; old_ttrating=1350; oldi_rating=4723;
#                              opt_laps_complete=0; position=0; qual_lap_time=-1;
#                              reason_out=Running; reason_out_id=0; starting_position=0;
#                              starting_position_in_class=0; suit=; team_id=-306596; watched=False;
#                              weight_penalty_kg=-1}}
# drop_race                  : False
# finish_position            : 0
# finish_position_in_class   : 0
# friend                     : False
# incidents                  : 14
# interval                   : 0
# laps_complete              : 172
# laps_lead                  : 124
# league_agg_points          : 385
# league_points              : 350
# license_change_oval        : -1
# license_change_road        : -1
# livery                     : @{car_id=168; car_number=5; color1=2a3795; color2=ed2129;
#                              color3=ffffff; number_color1=ffffff; number_color2=777777;
#                              number_color3=000000; number_font=0; number_slant=0; pattern=0;
#                              rim_type=-1; sponsor1=0; sponsor2=0; wheel_color=}
# max_pct_fuel_fill          : -1
# multiplier                 : 1
# new_cpi                    : 0
# new_license_level          : 0
# new_sub_level              : 0
# new_ttrating               : 0
# newi_rating                : 0
# old_cpi                    : 0
# old_license_level          : 0
# old_sub_level              : 0
# old_ttrating               : 0
# oldi_rating                : 0
# opt_laps_complete          : 0
# position                   : 0
# qual_lap_time              : -1
# reason_out                 : Running
# reason_out_id              : 0
# starting_position          : 0
# starting_position_in_class : 0
# suit                       : @{color1=0db700; color2=000000; color3=ffffff; pattern=2}
# team_id                    : -306596
# watched                    : False
# weight_penalty_kg          : -1
#
# aggregate_champ_points     : 352
# ai                         : False
# average_lap                : 838904
# best_lap_num               : 167
# best_lap_time              : 806942
# best_nlaps_num             : -1
# best_nlaps_time            : -1
# best_qual_lap_at           : 1/1/1970 12:00:00 AM
# best_qual_lap_num          : -1
# best_qual_lap_time         : -1
# car_class_id               : 4029
# car_class_name             : GTP
# car_class_short_name       : GTP
# car_id                     : 168
# car_name                   : Cadillac V-Series.R GTP
# champ_points               : 320
# class_interval             : 37821
# club_id                    : -1
# club_points                : 0
# display_name               : M4SKED DEVILS RED
# division                   : -1
# driver_results             : {@{aggregate_champ_points=320; ai=False; average_lap=822008;
#                              best_lap_num=167; best_lap_time=806942; best_nlaps_num=-1;
#                              best_nlaps_time=-1; best_qual_lap_at=1/1/1970 12:00:00 AM;
#                              best_qual_lap_num=-1; best_qual_lap_time=-1; car_class_id=4029;
#                              car_class_name=GTP; car_class_short_name=GTP; car_id=168;
#                              car_name=Cadillac V-Series.R GTP; champ_points=320;
#                              class_interval=37821; club_id=38; club_name=Iberia; club_points=0;
#                              club_shortname=Iberia; cust_id=552913; display_name=Sergio Borja;
#                              division=-1; drop_race=False; finish_position=1;
#                              finish_position_in_class=1; friend=False; helmet=; incidents=17;
#                              interval=37821; laps_complete=108; laps_lead=40;
#                              league_agg_points=320; league_points=320; license_change_oval=-1;
#                              license_change_road=-1; livery=; max_pct_fuel_fill=-1; multiplier=1;
#                              new_cpi=89.64606; new_license_level=20; new_sub_level=435;
#                              new_ttrating=1376; newi_rating=5964; old_cpi=89.64606;
#                              old_license_level=20; old_sub_level=435; old_ttrating=1376;
#                              oldi_rating=5964; opt_laps_complete=0; position=1; qual_lap_time=-1;
#                              reason_out=Running; reason_out_id=0; starting_position=1;
#                              starting_position_in_class=1; suit=; team_id=-147029; watched=False;
#                              weight_penalty_kg=-1}, @{aggregate_champ_points=320; ai=False;
#                              average_lap=831572; best_lap_num=138; best_lap_time=813354;
#                              best_nlaps_num=-1; best_nlaps_time=-1; best_qual_lap_at=1/1/1970
#                              12:00:00 AM; best_qual_lap_num=-1; best_qual_lap_time=-1;
#                              car_class_id=4029; car_class_name=GTP; car_class_short_name=GTP;
#                              car_id=168; car_name=Cadillac V-Series.R GTP; champ_points=320;
#                              class_interval=37821; club_id=38; club_name=Iberia; club_points=0;
#                              club_shortname=Iberia; cust_id=207525; display_name=Álvaro García;
#                              division=-1; drop_race=False; finish_position=1;
#                              finish_position_in_class=1; friend=False; helmet=; incidents=10;
#                              interval=37821; laps_complete=64; laps_lead=7; league_agg_points=320;
#                              league_points=320; license_change_oval=-1; license_change_road=-1;
#                              livery=; max_pct_fuel_fill=-1; multiplier=1; new_cpi=50.387573;
#                              new_license_level=18; new_sub_level=263; new_ttrating=1384;
#                              newi_rating=4376; old_cpi=50.387573; old_license_level=18;
#                              old_sub_level=263; old_ttrating=1384; oldi_rating=4376;
#                              opt_laps_complete=0; position=1; qual_lap_time=-1;
#                              reason_out=Running; reason_out_id=0; starting_position=1;
#                              starting_position_in_class=1; suit=; team_id=-147029; watched=False;
#                              weight_penalty_kg=-1}}
# drop_race                  : False
# finish_position            : 1
# finish_position_in_class   : 1
# friend                     : False
# incidents                  : 27
# interval                   : 37821
# laps_complete              : 172
# laps_lead                  : 47
# league_agg_points          : 352
# league_points              : 320
# license_change_oval        : -1
# license_change_road        : -1
# livery                     : @{car_id=168; car_number=7; color1=00000f; color2=ff0000;
#                              color3=00533f; number_color1=ffffff; number_color2=777777;
#                              number_color3=000000; number_font=0; number_slant=0; pattern=4;
#                              rim_type=-1; sponsor1=0; sponsor2=0; wheel_color=}
# max_pct_fuel_fill          : -1
# multiplier                 : 1
# new_cpi                    : 0
# new_license_level          : 0
# new_sub_level              : 0
# new_ttrating               : 0
# newi_rating                : 0
# old_cpi                    : 0
# old_license_level          : 0
# old_sub_level              : 0
# old_ttrating               : 0
# oldi_rating                : 0
# opt_laps_complete          : 0
# position                   : 1
# qual_lap_time              : -1
# reason_out                 : Running
# reason_out_id              : 0
# starting_position          : 1
# starting_position_in_class : 1
# suit                       : @{color1=44f85a; color2=474343; color3=666666; pattern=11}
# team_id                    : -147029
# watched                    : False
# weight_penalty_kg          : -1
#
# aggregate_champ_points     : 315
# ai                         : False
# average_lap                : 845416
# best_lap_num               : 168
# best_lap_time              : 805544
# best_nlaps_num             : -1
# best_nlaps_time            : -1
# best_qual_lap_at           : 1/1/1970 12:00:00 AM
# best_qual_lap_num          : -1
# best_qual_lap_time         : -1
# car_class_id               : 4029
# car_class_name             : GTP
# car_class_short_name       : GTP
# car_id                     : 168
# car_name                   : Cadillac V-Series.R GTP
# champ_points               : 300
# class_interval             : -1
# club_id                    : -1
# club_points                : 0
# display_name               : NIX e-Sports 1
# division                   : -1
# driver_results             : {@{aggregate_champ_points=300; ai=False; average_lap=837760;
#                              best_lap_num=168; best_lap_time=805544; best_nlaps_num=-1;
#                              best_nlaps_time=-1; best_qual_lap_at=1/1/1970 12:00:00 AM;
#                              best_qual_lap_num=-1; best_qual_lap_time=-1; car_class_id=4029;
#                              car_class_name=GTP; car_class_short_name=GTP; car_id=168;
#                              car_name=Cadillac V-Series.R GTP; champ_points=300;
#                              class_interval=-1; club_id=38; club_name=Iberia; club_points=0;
#                              club_shortname=Iberia; cust_id=197376; display_name=Albert Blanc
#                              Agenjo; division=-1; drop_race=False; finish_position=2;
#                              finish_position_in_class=2; friend=False; helmet=; incidents=22;
#                              interval=-1; laps_complete=133; laps_lead=0; league_agg_points=300;
#                              league_points=300; license_change_oval=-1; license_change_road=-1;
#                              livery=; max_pct_fuel_fill=-1; multiplier=1; new_cpi=54.581253;
#                              new_license_level=18; new_sub_level=275; new_ttrating=1323;
#                              newi_rating=5534; old_cpi=54.581253; old_license_level=18;
#                              old_sub_level=275; old_ttrating=1323; oldi_rating=5534;
#                              opt_laps_complete=0; position=2; qual_lap_time=-1;
#                              reason_out=Running; reason_out_id=0; starting_position=40;
#                              starting_position_in_class=15; suit=; team_id=-226674; watched=False;
#                              weight_penalty_kg=-1}, @{aggregate_champ_points=300; ai=False;
#                              average_lap=838899; best_lap_num=75; best_lap_time=821875;
#                              best_nlaps_num=-1; best_nlaps_time=-1; best_qual_lap_at=1/1/1970
#                              12:00:00 AM; best_qual_lap_num=-1; best_qual_lap_time=-1;
#                              car_class_id=4029; car_class_name=GTP; car_class_short_name=GTP;
#                              car_id=168; car_name=Cadillac V-Series.R GTP; champ_points=300;
#                              class_interval=-1; club_id=38; club_name=Iberia; club_points=0;
#                              club_shortname=Iberia; cust_id=528268; display_name=Diego Cayón;
#                              division=-1; drop_race=False; finish_position=2;
#                              finish_position_in_class=2; friend=False; helmet=; incidents=3;
#                              interval=-1; laps_complete=38; laps_lead=0; league_agg_points=300;
#                              league_points=300; license_change_oval=-1; license_change_road=-1;
#                              livery=; max_pct_fuel_fill=-1; multiplier=1; new_cpi=35.384926;
#                              new_license_level=15; new_sub_level=310; new_ttrating=1375;
#                              newi_rating=2636; old_cpi=35.384926; old_license_level=15;
#                              old_sub_level=310; old_ttrating=1375; oldi_rating=2636;
#                              opt_laps_complete=0; position=2; qual_lap_time=-1;
#                              reason_out=Running; reason_out_id=0; starting_position=40;
#                              starting_position_in_class=15; suit=; team_id=-226674; watched=False;
#                              weight_penalty_kg=-1}}
# drop_race                  : False
# finish_position            : 2
# finish_position_in_class   : 2
# friend                     : False
# incidents                  : 25
# interval                   : -1
# laps_complete              : 171
# laps_lead                  : 0
# league_agg_points          : 315
# league_points              : 300
# license_change_oval        : -1
# license_change_road        : -1
# livery                     : @{car_id=168; car_number=14; color1=2a3795; color2=ed2129;
#                              color3=ffffff; number_color1=ffffff; number_color2=777777;
#                              number_color3=000000; number_font=0; number_slant=0; pattern=24;
#                              rim_type=0; sponsor1=0; sponsor2=0; wheel_color=252525}
# max_pct_fuel_fill          : -1
# multiplier                 : 1
# new_cpi                    : 0
# new_license_level          : 0
# new_sub_level              : 0
# new_ttrating               : 0
# newi_rating                : 0
# old_cpi                    : 0
# old_license_level          : 0
# old_sub_level              : 0
# old_ttrating               : 0
# oldi_rating                : 0
# opt_laps_complete          : 0
# position                   : 2
# qual_lap_time              : -1
# reason_out                 : Running
# reason_out_id              : 0
# starting_position          : 40
# starting_position_in_class : 15
# suit                       : @{color1=131311; color2=111113; color3=e13333; pattern=2}
# team_id                    : -226674
# watched                    : False
# weight_penalty_kg          : -1
#
# aggregate_champ_points     : 308
# ai                         : False
# average_lap                : 846399
# best_lap_num               : 154
# best_lap_time              : 814878
# best_nlaps_num             : -1
# best_nlaps_time            : -1
# best_qual_lap_at           : 1/1/1970 12:00:00 AM
# best_qual_lap_num          : -1
# best_qual_lap_time         : -1
# car_class_id               : 4029
# car_class_name             : GTP
# car_class_short_name       : GTP
# car_id                     : 168
# car_name                   : Cadillac V-Series.R GTP
# champ_points               : 280
# class_interval             : -1
# club_id                    : -1
# club_points                : 0
# display_name               : Magic Arrow #55
# division                   : -1
# driver_results             : {@{aggregate_champ_points=280; ai=False; average_lap=833476;
#                              best_lap_num=154; best_lap_time=814878; best_nlaps_num=-1;
#                              best_nlaps_time=-1; best_qual_lap_at=1/1/1970 12:00:00 AM;
#                              best_qual_lap_num=-1; best_qual_lap_time=-1; car_class_id=4029;
#                              car_class_name=GTP; car_class_short_name=GTP; car_id=168;
#                              car_name=Cadillac V-Series.R GTP; champ_points=280;
#                              class_interval=-1; club_id=46; club_name=Central-Eastern Europe;
#                              club_points=0; club_shortname=Central-Eastern Europe; cust_id=620347;
#                              display_name=Norbert Tamas; division=-1; drop_race=False;
#                              finish_position=3; finish_position_in_class=3; friend=False; helmet=;
#                              incidents=3; interval=-1; laps_complete=94; laps_lead=1;
#                              league_agg_points=280; league_points=280; license_change_oval=-1;
#                              license_change_road=-1; livery=; max_pct_fuel_fill=-1; multiplier=1;
#                              new_cpi=127.34236; new_license_level=20; new_sub_level=489;
#                              new_ttrating=1350; newi_rating=5737; old_cpi=127.34236;
#                              old_license_level=20; old_sub_level=489; old_ttrating=1350;
#                              oldi_rating=5737; opt_laps_complete=0; position=3; qual_lap_time=-1;
#                              reason_out=Running; reason_out_id=0; starting_position=3;
#                              starting_position_in_class=3; suit=; team_id=-288087; watched=False;
#                              weight_penalty_kg=-1}, @{aggregate_champ_points=280; ai=False;
#                              average_lap=837196; best_lap_num=107; best_lap_time=826022;
#                              best_nlaps_num=-1; best_nlaps_time=-1; best_qual_lap_at=1/1/1970
#                              12:00:00 AM; best_qual_lap_num=-1; best_qual_lap_time=-1;
#                              car_class_id=4029; car_class_name=GTP; car_class_short_name=GTP;
#                              car_id=168; car_name=Cadillac V-Series.R GTP; champ_points=280;
#                              class_interval=-1; club_id=40; club_name=Benelux; club_points=0;
#                              club_shortname=Benelux; cust_id=684015; display_name=Eran Aviner;
#                              division=-1; drop_race=False; finish_position=3;
#                              finish_position_in_class=3; friend=False; helmet=; incidents=8;
#                              interval=-1; laps_complete=39; laps_lead=0; league_agg_points=280;
#                              league_points=280; license_change_oval=-1; license_change_road=-1;
#                              livery=; max_pct_fuel_fill=-1; multiplier=1; new_cpi=89.63309;
#                              new_license_level=20; new_sub_level=435; new_ttrating=1350;
#                              newi_rating=3221; old_cpi=89.63309; old_license_level=20;
#                              old_sub_level=435; old_ttrating=1350; oldi_rating=3221;
#                              opt_laps_complete=0; position=3; qual_lap_time=-1;
#                              reason_out=Running; reason_out_id=0; starting_position=3;
#                              starting_position_in_class=3; suit=; team_id=-288087; watched=False;
#                              weight_penalty_kg=-1}, @{aggregate_champ_points=280; ai=False;
#                              average_lap=836866; best_lap_num=73; best_lap_time=816836;
#                              best_nlaps_num=-1; best_nlaps_time=-1; best_qual_lap_at=1/1/1970
#                              12:00:00 AM; best_qual_lap_num=-1; best_qual_lap_time=-1;
#                              car_class_id=4029; car_class_name=GTP; car_class_short_name=GTP;
#                              car_id=168; car_name=Cadillac V-Series.R GTP; champ_points=280;
#                              class_interval=-1; club_id=46; club_name=Central-Eastern Europe;
#                              club_points=0; club_shortname=Central-Eastern Europe; cust_id=477938;
#                              display_name=Balazs Turoczy; division=-1; drop_race=False;
#                              finish_position=3; finish_position_in_class=3; friend=False; helmet=;
#                              incidents=10; interval=-1; laps_complete=38; laps_lead=0;
#                              league_agg_points=280; league_points=280; license_change_oval=-1;
#                              license_change_road=-1; livery=; max_pct_fuel_fill=-1; multiplier=1;
#                              new_cpi=62.148563; new_license_level=19; new_sub_level=339;
#                              new_ttrating=1230; newi_rating=4170; old_cpi=62.148563;
#                              old_license_level=19; old_sub_level=339; old_ttrating=1230;
#                              oldi_rating=4170; opt_laps_complete=0; position=3; qual_lap_time=-1;
#                              reason_out=Running; reason_out_id=0; starting_position=3;
#                              starting_position_in_class=3; suit=; team_id=-288087; watched=False;
#                              weight_penalty_kg=-1}}
# drop_race                  : False
# finish_position            : 3
# finish_position_in_class   : 3
# friend                     : False
# incidents                  : 21
# interval                   : -1
# laps_complete              : 171
# laps_lead                  : 1
# league_agg_points          : 308
# league_points              : 280
# license_change_oval        : -1
# license_change_road        : -1
# livery                     : @{car_id=168; car_number=55; color1=6331a4; color2=e8e3e3;
#                              color3=000000; number_color1=f1eef4; number_color2=000000;
#                              number_color3=ebeaea; number_font=0; number_slant=0; pattern=18;
#                              rim_type=-1; sponsor1=0; sponsor2=0; wheel_color=}
# max_pct_fuel_fill          : -1
# multiplier                 : 1
# new_cpi                    : 0
# new_license_level          : 0
# new_sub_level              : 0
# new_ttrating               : 0
# newi_rating                : 0
# old_cpi                    : 0
# old_license_level          : 0
# old_sub_level              : 0
# old_ttrating               : 0
# oldi_rating                : 0
# opt_laps_complete          : 0
# position                   : 3
# qual_lap_time              : -1
# reason_out                 : Running
# reason_out_id              : 0
# starting_position          : 3
# starting_position_in_class : 3
# suit                       : @{color1=f26522; color2=090a0e; color3=00aeef; pattern=20}
# team_id                    : -288087
# watched                    : False
# weight_penalty_kg          : -1
#
# aggregate_champ_points     : 282
# ai                         : False
# average_lap                : 848597
# best_lap_num               : 85
# best_lap_time              : 816670
# best_nlaps_num             : -1
# best_nlaps_time            : -1
# best_qual_lap_at           : 1/1/1970 12:00:00 AM
# best_qual_lap_num          : -1
# best_qual_lap_time         : -1
# car_class_id               : 4029
# car_class_name             : GTP
# car_class_short_name       : GTP
# car_id                     : 170
# car_name                   : Acura ARX-06 GTP
# champ_points               : 260
# class_interval             : -1
# club_id                    : -1
# club_points                : 0
# display_name               : Prestanda NOMAD #256
# division                   : -1
# driver_results             : {@{aggregate_champ_points=260; ai=False; average_lap=846623;
#                              best_lap_num=85; best_lap_time=816670; best_nlaps_num=-1;
#                              best_nlaps_time=-1; best_qual_lap_at=1/1/1970 12:00:00 AM;
#                              best_qual_lap_num=-1; best_qual_lap_time=-1; car_class_id=4029;
#                              car_class_name=GTP; car_class_short_name=GTP; car_id=170;
#                              car_name=Acura ARX-06 GTP; champ_points=260; class_interval=-1;
#                              club_id=36; club_name=UK and I; club_points=0; club_shortname=UK and
#                              I; cust_id=699233; display_name=Oliver E Bunn; division=-1;
#                              drop_race=False; finish_position=4; finish_position_in_class=4;
#                              friend=False; helmet=; incidents=11; interval=-1; laps_complete=94;
#                              laps_lead=0; league_agg_points=260; league_points=260;
#                              license_change_oval=-1; license_change_road=-1; livery=;
#                              max_pct_fuel_fill=-1; multiplier=1; new_cpi=47.109264;
#                              new_license_level=15; new_sub_level=353; new_ttrating=1270;
#                              newi_rating=3605; old_cpi=47.109264; old_license_level=15;
#                              old_sub_level=353; old_ttrating=1270; oldi_rating=3605;
#                              opt_laps_complete=0; position=4; qual_lap_time=-1;
#                              reason_out=Running; reason_out_id=0; starting_position=8;
#                              starting_position_in_class=8; suit=; team_id=-289887; watched=False;
#                              weight_penalty_kg=-1}, @{aggregate_champ_points=260; ai=False;
#                              average_lap=841507; best_lap_num=165; best_lap_time=822628;
#                              best_nlaps_num=-1; best_nlaps_time=-1; best_qual_lap_at=1/1/1970
#                              12:00:00 AM; best_qual_lap_num=-1; best_qual_lap_time=-1;
#                              car_class_id=4029; car_class_name=GTP; car_class_short_name=GTP;
#                              car_id=170; car_name=Acura ARX-06 GTP; champ_points=260;
#                              class_interval=-1; club_id=36; club_name=UK and I; club_points=0;
#                              club_shortname=UK and I; cust_id=225827; display_name=Taylor Lane;
#                              division=-1; drop_race=False; finish_position=4;
#                              finish_position_in_class=4; friend=False; helmet=; incidents=10;
#                              interval=-1; laps_complete=76; laps_lead=0; league_agg_points=260;
#                              league_points=260; license_change_oval=-1; license_change_road=-1;
#                              livery=; max_pct_fuel_fill=-1; multiplier=1; new_cpi=109.9615;
#                              new_license_level=20; new_sub_level=467; new_ttrating=1303;
#                              newi_rating=3591; old_cpi=109.9615; old_license_level=20;
#                              old_sub_level=467; old_ttrating=1303; oldi_rating=3591;
#                              opt_laps_complete=0; position=4; qual_lap_time=-1;
#                              reason_out=Running; reason_out_id=0; starting_position=8;
#                              starting_position_in_class=8; suit=; team_id=-289887; watched=False;
#                              weight_penalty_kg=-1}}
# drop_race                  : False
# finish_position            : 4
# finish_position_in_class   : 4
# friend                     : False
# incidents                  : 21
# interval                   : -1
# laps_complete              : 170
# laps_lead                  : 0
# league_agg_points          : 282
# league_points              : 260
# license_change_oval        : -1
# license_change_road        : -1
# livery                     : @{car_id=170; car_number=28; color1=00dbc9; color2=013037;
#                              color3=00dbc9; number_color1=013037; number_color2=00dbc9;
#                              number_color3=013037; number_font=0; number_slant=0; pattern=3;
#                              rim_type=-1; sponsor1=0; sponsor2=0; wheel_color=}
# max_pct_fuel_fill          : -1
# multiplier                 : 1
# new_cpi                    : 0
# new_license_level          : 0
# new_sub_level              : 0
# new_ttrating               : 0
# newi_rating                : 0
# old_cpi                    : 0
# old_license_level          : 0
# old_sub_level              : 0
# old_ttrating               : 0
# oldi_rating                : 0
# opt_laps_complete          : 0
# position                   : 4
# qual_lap_time              : -1
# reason_out                 : Running
# reason_out_id              : 0
# starting_position          : 8
# starting_position_in_class : 8
# suit                       : @{color1=194c5f; color2=ffffff; color3=ffd825; pattern=13}
# team_id                    : -289887
# watched                    : False
# weight_penalty_kg          : -1
#
# aggregate_champ_points     : 276
# ai                         : False
# average_lap                : 848769
# best_lap_num               : 69
# best_lap_time              : 815910
# best_nlaps_num             : -1
# best_nlaps_time            : -1
# best_qual_lap_at           : 1/1/1970 12:00:00 AM
# best_qual_lap_num          : -1
# best_qual_lap_time         : -1
# car_class_id               : 4029
# car_class_name             : GTP
# car_class_short_name       : GTP
# car_id                     : 168
# car_name                   : Cadillac V-Series.R GTP
# champ_points               : 250
# class_interval             : -1
# club_id                    : -1
# club_points                : 0
# display_name               : M4sked Devils BLUE
# division                   : -1
# driver_results             : {@{aggregate_champ_points=250; ai=False; average_lap=848044;
#                              best_lap_num=166; best_lap_time=820000; best_nlaps_num=-1;
#                              best_nlaps_time=-1; best_qual_lap_at=1/1/1970 12:00:00 AM;
#                              best_qual_lap_num=-1; best_qual_lap_time=-1; car_class_id=4029;
#                              car_class_name=GTP; car_class_short_name=GTP; car_id=168;
#                              car_name=Cadillac V-Series.R GTP; champ_points=250;
#                              class_interval=-1; club_id=38; club_name=Iberia; club_points=0;
#                              club_shortname=Iberia; cust_id=435163; display_name=Álvaro Gutierrez;
#                              division=-1; drop_race=False; finish_position=5;
#                              finish_position_in_class=5; friend=False; helmet=; incidents=14;
#                              interval=-1; laps_complete=92; laps_lead=0; league_agg_points=250;
#                              league_points=250; license_change_oval=-1; license_change_road=-1;
#                              livery=; max_pct_fuel_fill=-1; multiplier=1; new_cpi=177.04628;
#                              new_license_level=20; new_sub_level=499; new_ttrating=1350;
#                              newi_rating=3251; old_cpi=177.04628; old_license_level=20;
#                              old_sub_level=499; old_ttrating=1350; oldi_rating=3251;
#                              opt_laps_complete=0; position=5; qual_lap_time=-1;
#                              reason_out=Running; reason_out_id=0; starting_position=4;
#                              starting_position_in_class=4; suit=; team_id=-135937; watched=False;
#                              weight_penalty_kg=-1}, @{aggregate_champ_points=250; ai=False;
#                              average_lap=841614; best_lap_num=69; best_lap_time=815910;
#                              best_nlaps_num=-1; best_nlaps_time=-1; best_qual_lap_at=1/1/1970
#                              12:00:00 AM; best_qual_lap_num=-1; best_qual_lap_time=-1;
#                              car_class_id=4029; car_class_name=GTP; car_class_short_name=GTP;
#                              car_id=168; car_name=Cadillac V-Series.R GTP; champ_points=250;
#                              class_interval=-1; club_id=38; club_name=Iberia; club_points=0;
#                              club_shortname=Iberia; cust_id=558947; display_name=Pablo Javier
#                              Ruiz; division=-1; drop_race=False; finish_position=5;
#                              finish_position_in_class=5; friend=False; helmet=; incidents=17;
#                              interval=-1; laps_complete=78; laps_lead=0; league_agg_points=250;
#                              league_points=250; license_change_oval=-1; license_change_road=-1;
#                              livery=; max_pct_fuel_fill=-1; multiplier=1; new_cpi=29.79083;
#                              new_license_level=17; new_sub_level=139; new_ttrating=1292;
#                              newi_rating=3567; old_cpi=29.79083; old_license_level=17;
#                              old_sub_level=139; old_ttrating=1292; oldi_rating=3567;
#                              opt_laps_complete=0; position=5; qual_lap_time=-1;
#                              reason_out=Running; reason_out_id=0; starting_position=4;
#                              starting_position_in_class=4; suit=; team_id=-135937; watched=False;
#                              weight_penalty_kg=-1}}
# drop_race                  : False
# finish_position            : 5
# finish_position_in_class   : 5
# friend                     : False
# incidents                  : 31
# interval                   : -1
# laps_complete              : 170
# laps_lead                  : 0
# league_agg_points          : 276
# league_points              : 250
# license_change_oval        : -1
# license_change_road        : -1
# livery                     : @{car_id=168; car_number=10; color1=00000f; color2=ff0000;
#                              color3=005f4b; number_color1=ffffff; number_color2=00614d;
#                              number_color3=000000; number_font=0; number_slant=0; pattern=4;
#                              rim_type=1; sponsor1=0; sponsor2=0; wheel_color=000000}
# max_pct_fuel_fill          : -1
# multiplier                 : 1
# new_cpi                    : 0
# new_license_level          : 0
# new_sub_level              : 0
# new_ttrating               : 0
# newi_rating                : 0
# old_cpi                    : 0
# old_license_level          : 0
# old_sub_level              : 0
# old_ttrating               : 0
# oldi_rating                : 0
# opt_laps_complete          : 0
# position                   : 5
# qual_lap_time              : -1
# reason_out                 : Running
# reason_out_id              : 0
# starting_position          : 4
# starting_position_in_class : 4
# suit                       : @{color1=44f85a; color2=474343; color3=666666; pattern=11}
# team_id                    : -135937
# watched                    : False
# weight_penalty_kg          : -1
#
# aggregate_champ_points     : 258
# ai                         : False
# average_lap                : 848967
# best_lap_num               : 157
# best_lap_time              : 817069
# best_nlaps_num             : -1
# best_nlaps_time            : -1
# best_qual_lap_at           : 1/1/1970 12:00:00 AM
# best_qual_lap_num          : -1
# best_qual_lap_time         : -1
# car_class_id               : 4029
# car_class_name             : GTP
# car_class_short_name       : GTP
# car_id                     : 170
# car_name                   : Acura ARX-06 GTP
# champ_points               : 240
# class_interval             : -1
# club_id                    : -1
# club_points                : 0
# display_name               : Stop N' Go Racing
# division                   : -1
# driver_results             : {@{aggregate_champ_points=240; ai=False; average_lap=849006;
#                              best_lap_num=95; best_lap_time=820885; best_nlaps_num=-1;
#                              best_nlaps_time=-1; best_qual_lap_at=1/1/1970 12:00:00 AM;
#                              best_qual_lap_num=-1; best_qual_lap_time=-1; car_class_id=4029;
#                              car_class_name=GTP; car_class_short_name=GTP; car_id=170;
#                              car_name=Acura ARX-06 GTP; champ_points=240; class_interval=-1;
#                              club_id=43; club_name=Scandinavia; club_points=0;
#                              club_shortname=Scandinavia; cust_id=115054; display_name=Morten
#                              Kofoed; division=-1; drop_race=False; finish_position=6;
#                              finish_position_in_class=6; friend=False; helmet=; incidents=18;
#                              interval=-1; laps_complete=102; laps_lead=0; league_agg_points=240;
#                              league_points=240; license_change_oval=-1; license_change_road=-1;
#                              livery=; max_pct_fuel_fill=-1; multiplier=1; new_cpi=482.4439;
#                              new_license_level=20; new_sub_level=499; new_ttrating=1517;
#                              newi_rating=2531; old_cpi=482.4439; old_license_level=20;
#                              old_sub_level=499; old_ttrating=1517; oldi_rating=2531;
#                              opt_laps_complete=0; position=6; qual_lap_time=-1;
#                              reason_out=Running; reason_out_id=0; starting_position=12;
#                              starting_position_in_class=12; suit=; team_id=-258321; watched=False;
#                              weight_penalty_kg=-1}, @{aggregate_champ_points=240; ai=False;
#                              average_lap=839626; best_lap_num=157; best_lap_time=817069;
#                              best_nlaps_num=-1; best_nlaps_time=-1; best_qual_lap_at=1/1/1970
#                              12:00:00 AM; best_qual_lap_num=-1; best_qual_lap_time=-1;
#                              car_class_id=4029; car_class_name=GTP; car_class_short_name=GTP;
#                              car_id=170; car_name=Acura ARX-06 GTP; champ_points=240;
#                              class_interval=-1; club_id=43; club_name=Scandinavia; club_points=0;
#                              club_shortname=Scandinavia; cust_id=556217; display_name=Thomas Mørk;
#                              division=-1; drop_race=False; finish_position=6;
#                              finish_position_in_class=6; friend=False; helmet=; incidents=9;
#                              interval=-1; laps_complete=68; laps_lead=0; league_agg_points=240;
#                              league_points=240; license_change_oval=-1; license_change_road=-1;
#                              livery=; max_pct_fuel_fill=-1; multiplier=1; new_cpi=105.189285;
#                              new_license_level=20; new_sub_level=460; new_ttrating=1350;
#                              newi_rating=3219; old_cpi=105.189285; old_license_level=20;
#                              old_sub_level=460; old_ttrating=1350; oldi_rating=3219;
#                              opt_laps_complete=0; position=6; qual_lap_time=-1;
#                              reason_out=Running; reason_out_id=0; starting_position=12;
#                              starting_position_in_class=12; suit=; team_id=-258321; watched=False;
#                              weight_penalty_kg=-1}}
# drop_race                  : False
# finish_position            : 6
# finish_position_in_class   : 6
# friend                     : False
# incidents                  : 27
# interval                   : -1
# laps_complete              : 170
# laps_lead                  : 0
# league_agg_points          : 258
# league_points              : 240
# license_change_oval        : -1
# license_change_road        : -1
# livery                     : @{car_id=170; car_number=39; color1=ff0000; color2=00ff00;
#                              color3=0000ff; number_color1=ffffff; number_color2=777777;
#                              number_color3=000000; number_font=0; number_slant=0; pattern=2;
#                              rim_type=-1; sponsor1=0; sponsor2=0; wheel_color=}
# max_pct_fuel_fill          : -1
# multiplier                 : 1
# new_cpi                    : 0
# new_license_level          : 0
# new_sub_level              : 0
# new_ttrating               : 0
# newi_rating                : 0
# old_cpi                    : 0
# old_license_level          : 0
# old_sub_level              : 0
# old_ttrating               : 0
# oldi_rating                : 0
# opt_laps_complete          : 0
# position                   : 6
# qual_lap_time              : -1
# reason_out                 : Running
# reason_out_id              : 0
# starting_position          : 12
# starting_position_in_class : 12
# suit                       : @{color1=ffffff; color2=b52d2d; color3=c42d2d; pattern=24}
# team_id                    : -258321
# watched                    : False
# weight_penalty_kg          : -1
#
# aggregate_champ_points     : 254
# ai                         : False
# average_lap                : 850292
# best_lap_num               : 28
# best_lap_time              : 820642
# best_nlaps_num             : -1
# best_nlaps_time            : -1
# best_qual_lap_at           : 1/1/1970 12:00:00 AM
# best_qual_lap_num          : -1
# best_qual_lap_time         : -1
# car_class_id               : 4029
# car_class_name             : GTP
# car_class_short_name       : GTP
# car_id                     : 168
# car_name                   : Cadillac V-Series.R GTP
# champ_points               : 230
# class_interval             : -1
# club_id                    : -1
# club_points                : 0
# display_name               : LITHIUM Motorsports
# division                   : -1
# driver_results             : {@{aggregate_champ_points=230; ai=False; average_lap=848721;
#                              best_lap_num=97; best_lap_time=821498; best_nlaps_num=-1;
#                              best_nlaps_time=-1; best_qual_lap_at=1/1/1970 12:00:00 AM;
#                              best_qual_lap_num=-1; best_qual_lap_time=-1; car_class_id=4029;
#                              car_class_name=GTP; car_class_short_name=GTP; car_id=168;
#                              car_name=Cadillac V-Series.R GTP; champ_points=230;
#                              class_interval=-1; club_id=26; club_name=Illinois; club_points=0;
#                              club_shortname=Illinois; cust_id=380152; display_name=Zachary
#                              Livengood; division=-1; drop_race=False; finish_position=7;
#                              finish_position_in_class=7; friend=False; helmet=; incidents=17;
#                              interval=-1; laps_complete=94; laps_lead=0; league_agg_points=230;
#                              league_points=230; license_change_oval=-1; license_change_road=-1;
#                              livery=; max_pct_fuel_fill=-1; multiplier=1; new_cpi=167.73935;
#                              new_license_level=20; new_sub_level=499; new_ttrating=1350;
#                              newi_rating=2876; old_cpi=167.73935; old_license_level=20;
#                              old_sub_level=499; old_ttrating=1350; oldi_rating=2876;
#                              opt_laps_complete=0; position=7; qual_lap_time=-1;
#                              reason_out=Running; reason_out_id=0; starting_position=6;
#                              starting_position_in_class=6; suit=; team_id=-53704; watched=False;
#                              weight_penalty_kg=-1}, @{aggregate_champ_points=230; ai=False;
#                              average_lap=843888; best_lap_num=28; best_lap_time=820642;
#                              best_nlaps_num=-1; best_nlaps_time=-1; best_qual_lap_at=1/1/1970
#                              12:00:00 AM; best_qual_lap_num=-1; best_qual_lap_time=-1;
#                              car_class_id=4029; car_class_name=GTP; car_class_short_name=GTP;
#                              car_id=168; car_name=Cadillac V-Series.R GTP; champ_points=230;
#                              class_interval=-1; club_id=40; club_name=Benelux; club_points=0;
#                              club_shortname=Benelux; cust_id=611888; display_name=Milo Speelman;
#                              division=-1; drop_race=False; finish_position=7;
#                              finish_position_in_class=7; friend=False; helmet=; incidents=11;
#                              interval=-1; laps_complete=76; laps_lead=0; league_agg_points=230;
#                              league_points=230; license_change_oval=-1; license_change_road=-1;
#                              livery=; max_pct_fuel_fill=-1; multiplier=1; new_cpi=53.285522;
#                              new_license_level=18; new_sub_level=272; new_ttrating=1350;
#                              newi_rating=2553; old_cpi=53.285522; old_license_level=18;
#                              old_sub_level=272; old_ttrating=1350; oldi_rating=2553;
#                              opt_laps_complete=0; position=7; qual_lap_time=-1;
#                              reason_out=Running; reason_out_id=0; starting_position=6;
#                              starting_position_in_class=6; suit=; team_id=-53704; watched=False;
#                              weight_penalty_kg=-1}}
# drop_race                  : False
# finish_position            : 7
# finish_position_in_class   : 7
# friend                     : False
# incidents                  : 28
# interval                   : -1
# laps_complete              : 170
# laps_lead                  : 0
# league_agg_points          : 254
# league_points              : 230
# license_change_oval        : -1
# license_change_road        : -1
# livery                     : @{car_id=168; car_number=34; color1=ffffff; color2=cccccc;
#                              color3=666666; number_color1=ffffff; number_color2=777777;
#                              number_color3=000000; number_font=1; number_slant=0; pattern=0;
#                              rim_type=-1; sponsor1=0; sponsor2=0; wheel_color=}
# max_pct_fuel_fill          : -1
# multiplier                 : 1
# new_cpi                    : 0
# new_license_level          : 0
# new_sub_level              : 0
# new_ttrating               : 0
# newi_rating                : 0
# old_cpi                    : 0
# old_license_level          : 0
# old_sub_level              : 0
# old_ttrating               : 0
# oldi_rating                : 0
# opt_laps_complete          : 0
# position                   : 7
# qual_lap_time              : -1
# reason_out                 : Running
# reason_out_id              : 0
# starting_position          : 6
# starting_position_in_class : 6
# ...
#                              average_lap=979763; best_lap_num=50; best_lap_time=939114;
#                              best_nlaps_num=-1; best_nlaps_time=-1; best_qual_lap_at=1/1/1970
#                              12:00:00 AM; best_qual_lap_num=-1; best_qual_lap_time=-1;
#                              car_class_id=4011; car_class_name=IMSA23;
#                              car_class_short_name=IMSA23; car_id=169; car_name=Porsche 911 GT3 R
#                              (992); champ_points=50; class_interval=-1; club_id=38;
#                              club_name=Iberia; club_points=0; club_shortname=Iberia;
#                              cust_id=636125; display_name=Hiago Martins; division=-1;
#                              drop_race=False; finish_position=40; finish_position_in_class=25;
#                              friend=False; helmet=; incidents=5; interval=-1; laps_complete=14;
#                              laps_lead=0; league_agg_points=50; league_points=50;
#                              license_change_oval=-1; license_change_road=-1; livery=;
#                              max_pct_fuel_fill=-1; multiplier=1; new_cpi=34.903114;
#                              new_license_level=18; new_sub_level=208; new_ttrating=1295;
#                              newi_rating=3650; old_cpi=34.903114; old_license_level=18;
#                              old_sub_level=208; old_ttrating=1295; oldi_rating=3650;
#                              opt_laps_complete=0; position=40; qual_lap_time=-1;
#                              reason_out=Disconnected; reason_out_id=32; starting_position=19;
#                              starting_position_in_class=4; suit=; team_id=-194019; watched=False;
#                              weight_penalty_kg=-1}}
# drop_race                  : False
# finish_position            : 40
# finish_position_in_class   : 25
# friend                     : False
# incidents                  : 22
# interval                   : -1
# laps_complete              : 51
# laps_lead                  : 0
# league_agg_points          : 76
# league_points              : 50
# license_change_oval        : -1
# license_change_road        : -1
# livery                     : @{car_id=169; car_number=264; color1=ffffff; color2=cccccc;
#                              color3=666666; number_color1=000000; number_color2=777777;
#                              number_color3=000000; number_font=0; number_slant=0; pattern=0;
#                              rim_type=-1; sponsor1=0; sponsor2=0; wheel_color=}
# max_pct_fuel_fill          : -1
# multiplier                 : 1
# new_cpi                    : 0
# new_license_level          : 0
# new_sub_level              : 0
# new_ttrating               : 0
# newi_rating                : 0
# old_cpi                    : 0
# old_license_level          : 0
# old_sub_level              : 0
# old_ttrating               : 0
# oldi_rating                : 0
# opt_laps_complete          : 0
# position                   : 40
# qual_lap_time              : -1
# reason_out                 : Disconnected
# reason_out_id              : 32
# starting_position          : 19
# starting_position_in_class : 4
# suit                       : @{color1=fdfafa; color2=1377c3; color3=060505; pattern=12}
# team_id                    : -194019
# watched                    : False
# weight_penalty_kg          : -1
#
# aggregate_champ_points     : 19
# ai                         : False
# average_lap                : 0
# best_lap_num               : -1
# best_lap_time              : -1
# best_nlaps_num             : -1
# best_nlaps_time            : -1
# best_qual_lap_at           : 1/1/1970 12:00:00 AM
# best_qual_lap_num          : -1
# best_qual_lap_time         : -1
# car_class_id               : 4029
# car_class_name             : GTP
# car_class_short_name       : GTP
# car_id                     : 174
# car_name                   : Porsche 963 GTP
# champ_points               : 0
# class_interval             : -1
# club_id                    : -1
# club_points                : 0
# display_name               : Race2Esport
# division                   : -1
# driver_results             : {@{aggregate_champ_points=0; ai=False; average_lap=861169;
#                              best_lap_num=122; best_lap_time=821930; best_nlaps_num=-1;
#                              best_nlaps_time=-1; best_qual_lap_at=1/1/1970 12:00:00 AM;
#                              best_qual_lap_num=-1; best_qual_lap_time=-1; car_class_id=4029;
#                              car_class_name=GTP; car_class_short_name=GTP; car_id=174;
#                              car_name=Porsche 963 GTP; champ_points=0; class_interval=-1;
#                              club_id=45; club_name=Brazil; club_points=0; club_shortname=Brazil;
#                              cust_id=46080; display_name=Cesar Cabral; division=-1;
#                              drop_race=False; finish_position=41; finish_position_in_class=15;
#                              friend=False; helmet=; incidents=28; interval=-1; laps_complete=128;
#                              laps_lead=0; league_agg_points=0; league_points=0;
#                              license_change_oval=-1; license_change_road=-1; livery=;
#                              max_pct_fuel_fill=-1; multiplier=1; new_cpi=107.546455;
#                              new_license_level=20; new_sub_level=463; new_ttrating=1679;
#                              newi_rating=3294; old_cpi=107.546455; old_license_level=20;
#                              old_sub_level=463; old_ttrating=1679; oldi_rating=3294;
#                              opt_laps_complete=0; position=41; qual_lap_time=-1;
#                              reason_out=DQ/Scoring Invalidated; reason_out_id=34;
#                              starting_position=11; starting_position_in_class=11; suit=;
#                              team_id=-201751; watched=False; weight_penalty_kg=-1}}
# drop_race                  : False
# finish_position            : 41
# finish_position_in_class   : 15
# friend                     : False
# incidents                  : 28
# interval                   : -1
# laps_complete              : 0
# laps_lead                  : 0
# league_agg_points          : 19
# league_points              : 0
# license_change_oval        : -1
# license_change_road        : -1
# livery                     : @{car_id=174; car_number=70; color1=ff0000; color2=00ff00;
#                              color3=0000ff; number_color1=ffffff; number_color2=777777;
#                              number_color3=000000; number_font=0; number_slant=0; pattern=1;
#                              rim_type=3; sponsor1=0; sponsor2=0; wheel_color=ffffff}
# max_pct_fuel_fill          : -1
# multiplier                 : 1
# new_cpi                    : 0
# new_license_level          : 0
# new_sub_level              : 0
# new_ttrating               : 0
# newi_rating                : 0
# old_cpi                    : 0
# old_license_level          : 0
# old_sub_level              : 0
# old_ttrating               : 0
# oldi_rating                : 0
# opt_laps_complete          : 0
# position                   : 41
# qual_lap_time              : -1
# reason_out                 : DQ/Scoring Invalidated
# reason_out_id              : 34
# starting_position          : 11
# starting_position_in_class : 11
# suit                       : @{color1=2e2e2e; color2=ffffff; color3=00d10a; pattern=32}
# team_id                    : -201751
# watched                    : False
# weight_penalty_kg          : -1
#
# aggregate_champ_points     : 48
# ai                         : False
# average_lap                : 0
# best_lap_num               : -1
# best_lap_time              : -1
# best_nlaps_num             : -1
# best_nlaps_time            : -1
# best_qual_lap_at           : 1/1/1970 12:00:00 AM
# best_qual_lap_num          : -1
# best_qual_lap_time         : -1
# car_class_id               : 4011
# car_class_name             : IMSA23
# car_class_short_name       : IMSA23
# car_id                     : 173
# car_name                   : Ferrari 296 GT3
# champ_points               : 40
# class_interval             : -1
# club_id                    : -1
# club_points                : 0
# display_name               : F Racing #GT3
# division                   : -1
# driver_results             : {@{aggregate_champ_points=40; ai=False; average_lap=974148;
#                              best_lap_num=42; best_lap_time=941953; best_nlaps_num=-1;
#                              best_nlaps_time=-1; best_qual_lap_at=1/1/1970 12:00:00 AM;
#                              best_qual_lap_num=-1; best_qual_lap_time=-1; car_class_id=4011;
#                              car_class_name=IMSA23; car_class_short_name=IMSA23; car_id=173;
#                              car_name=Ferrari 296 GT3; champ_points=40; class_interval=-1;
#                              club_id=42; club_name=DE-AT-CH; club_points=0;
#                              club_shortname=DE-AT-CH; cust_id=580757; display_name=Marco Andre
#                              Pinto; division=-1; drop_race=False; finish_position=42;
#                              finish_position_in_class=26; friend=False; helmet=; incidents=28;
#                              interval=-1; laps_complete=55; laps_lead=0; league_agg_points=40;
#                              league_points=40; license_change_oval=-1; license_change_road=-1;
#                              livery=; max_pct_fuel_fill=-1; multiplier=1; new_cpi=109.02658;
#                              new_license_level=20; new_sub_level=465; new_ttrating=1550;
#                              newi_rating=4635; old_cpi=109.02658; old_license_level=20;
#                              old_sub_level=465; old_ttrating=1550; oldi_rating=4635;
#                              opt_laps_complete=0; position=42; qual_lap_time=-1;
#                              reason_out=Disconnected; reason_out_id=32; starting_position=37;
#                              starting_position_in_class=22; suit=; team_id=-295369; watched=False;
#                              weight_penalty_kg=-1}}
# drop_race                  : False
# finish_position            : 42
# finish_position_in_class   : 26
# friend                     : False
# incidents                  : 28
# interval                   : -1
# laps_complete              : 0
# laps_lead                  : 0
# league_agg_points          : 48
# league_points              : 40
# license_change_oval        : -1
# license_change_road        : -1
# livery                     : @{car_id=173; car_number=11; color1=ff0000; color2=00ff00;
#                              color3=0000ff; number_color1=ffffff; number_color2=777777;
#                              number_color3=000000; number_font=0; number_slant=0; pattern=1;
#                              rim_type=-1; sponsor1=0; sponsor2=0; wheel_color=}
# max_pct_fuel_fill          : -1
# multiplier                 : 1
# new_cpi                    : 0
# new_license_level          : 0
# new_sub_level              : 0
# new_ttrating               : 0
# newi_rating                : 0
# old_cpi                    : 0
# old_license_level          : 0
# old_sub_level              : 0
# old_ttrating               : 0
# oldi_rating                : 0
# opt_laps_complete          : 0
# position                   : 42
# qual_lap_time              : -1
# reason_out                 : Disconnected
# reason_out_id              : 32
# starting_position          : 37
# starting_position_in_class : 22
# suit                       : @{color1=00aeef; color2=f26522; color3=0a0a0a; pattern=1}
# team_id                    : -295369
# watched                    : False
# weight_penalty_kg          : -1
#
# aggregate_champ_points     : 0
# ai                         : False
# average_lap                : 0
# best_lap_num               : -1
# best_lap_time              : -1
# best_nlaps_num             : -1
# best_nlaps_time            : -1
# best_qual_lap_at           : 1/1/1970 12:00:00 AM
# best_qual_lap_num          : -1
# best_qual_lap_time         : -1
# car_class_id               : 4011
# car_class_name             : IMSA23
# car_class_short_name       : IMSA23
# car_id                     : 132
# car_name                   : BMW M4 GT3
# champ_points               : 0
# class_interval             : -1
# club_id                    : -1
# club_points                : 0
# display_name               : PEC stewards
# division                   : -1
# driver_results             : {}
# drop_race                  : False
# finish_position            : 43
# finish_position_in_class   : 27
# friend                     : False
# incidents                  : 0
# interval                   : -1
# laps_complete              : 0
# laps_lead                  : 0
# league_agg_points          : 0
# league_points              : 0
# license_change_oval        : -1
# license_change_road        : -1
# livery                     : @{car_id=132; car_number=383; color1=2a3795; color2=ed2129;
#                              color3=ffffff; number_color1=ffffff; number_color2=777777;
#                              number_color3=000000; number_font=0; number_slant=0; pattern=0;
#                              rim_type=-1; sponsor1=0; sponsor2=0; wheel_color=}
# max_pct_fuel_fill          : -1
# multiplier                 : 1
# new_cpi                    : 0
# new_license_level          : 0
# new_sub_level              : 0
# new_ttrating               : 0
# newi_rating                : 0
# old_cpi                    : 0
# old_license_level          : 0
# old_sub_level              : 0
# old_ttrating               : 0
# oldi_rating                : 0
# opt_laps_complete          : 0
# position                   : 43
# qual_lap_time              : -1
# reason_out                 : DQ/Scoring Invalidated
# reason_out_id              : 34
# starting_position          : 42
# starting_position_in_class : 26
# suit                       : @{color1=d7162d; color2=efd600; color3=111111; pattern=1}
# team_id                    : -280178
# watched                    : False
# weight_penalty_kg          : -1
#
# aggregate_champ_points     : 0
# ai                         : False
# average_lap                : 0
# best_lap_num               : -1
# best_lap_time              : -1
# best_nlaps_num             : -1
# best_nlaps_time            : -1
# best_qual_lap_at           : 1/1/1970 12:00:00 AM
# best_qual_lap_num          : -1
# best_qual_lap_time         : -1
# car_class_id               : 4011
# car_class_name             : IMSA23
# car_class_short_name       : IMSA23
# car_id                     : 132
# car_name                   : BMW M4 GT3
# champ_points               : 0
# class_interval             : -1
# club_id                    : -1
# club_points                : 0
# display_name               : PEC Stewarts personal
# division                   : -1
# driver_results             : {}
# drop_race                  : False
# finish_position            : 44
# finish_position_in_class   : 28
# friend                     : False
# incidents                  : 0
# interval                   : -1
# laps_complete              : 0
# laps_lead                  : 0
# league_agg_points          : 0
# league_points              : 0
# license_change_oval        : -1
# license_change_road        : -1
# livery                     : @{car_id=132; car_number=69; color1=2a3795; color2=ed2129;
#                              color3=ffffff; number_color1=2a3795; number_color2=ed2229;
#                              number_color3=eeeeee; number_font=0; number_slant=0; pattern=0;
#                              rim_type=-1; sponsor1=0; sponsor2=0; wheel_color=}
# max_pct_fuel_fill          : -1
# multiplier                 : 1
# new_cpi                    : 0
# new_license_level          : 0
# new_sub_level              : 0
# new_ttrating               : 0
# newi_rating                : 0
# old_cpi                    : 0
# old_license_level          : 0
# old_sub_level              : 0
# old_ttrating               : 0
# oldi_rating                : 0
# opt_laps_complete          : 0
# position                   : 44
# qual_lap_time              : -1
# reason_out                 : DQ/Scoring Invalidated
# reason_out_id              : 34
# starting_position          : 43
# starting_position_in_class : 27
# suit                       : @{color1=372a75; color2=ffffff; color3=f1732e; pattern=1}
# team_id                    : -300131
# watched                    : False
# weight_penalty_kg          : -1

# %%
$resultjson = get-content .\iracing_result\iracing-result-64291778.json
$result = $resultjson | ConvertFrom-Json

$session_results = $result.session_results.where{$_.simsession_name -like "RACE"}.results
$class_results = $session_results.where{$_.car_class_name -like "GTP"}
$race_winner = $class_results.where{$_.finish_position_in_class -eq 0}
$race_totaltime = ($race_winner.average_lap * $race_winner.laps_complete)

#$session_results = $result.session_results.results
$final_result_col = @()
foreach ($session_result in $class_results){
    $car_number = $session_result.livery.car_number
    $behindlaps = $race_totaltime / $session_result.average_lap
    $factor = $session_result.average_lap/$race_winner.average_lap
    $behindtime = ($factor * $race_totaltime)
    $timedelta = $behindtime - $race_totaltime
    $final_result = $session_result | select car_class_name,display_name #,finish_position_in_class
    $final_result | add-member -NotePropertyName car_number -NotePropertyValue $car_number -Force
    $final_result | add-member -NotePropertyName laps -NotePropertyValue $behindlaps -Force
    $final_result | add-member -NotePropertyName time -NotePropertyValue ($behindtime/10000) -Force
    $final_result | add-member -NotePropertyName timedelta -NotePropertyValue ($timedelta/10000) -Force
    $final_result_col += $final_result
}

$final_result_col | ft -AutoSize
#$sessionresults = $result.session_results.result.display_name
# Out:
# RuntimeException:
# Line |
#   11 |      $behindlaps = $race_totaltime / $session_result.average_lap
#      |      ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#      | Attempted to divide by zero.
#
# car_class_name display_name           car_number    laps      time  timedelta
# -------------- ------------           ----------    ----      ----  ---------
# GTP            XBD Emiral Racing      5              172 14425.365          0
# GTP            M4SKED DEVILS RED      7          171.955 14429.149      3.784
# GTP            NIX e-Sports 1         14         170.630 14541.155    115.790
# GTP            Magic Arrow #55        55         170.432 14558.063    132.698
# GTP            Prestanda NOMAD #256   28         169.991 14595.868    170.504
# GTP            M4sked Devils BLUE     10         169.956 14598.827    173.462
# GTP            Stop N' Go Racing      39         169.917 14602.232    176.868
# GTP            LITHIUM Motorsports    34         169.652 14625.022    199.658
# GTP            Magic Arrow #56        56         169.513 14636.976    211.612
# GTP            IPM Gold               49         169.509 14637.338    211.973
# GTP            F Racing #LMDH         99         168.478 14726.967    301.602
# GTP            Future Racing Team Pro 18         168.150 14755.691    330.326
# GTP            GO! eSports GTP        23         167.697 14795.492    370.127
# GTP            Project Dynamic Green  71         161.221 15389.838    964.473
# GTP            Carbono eSports Black  30         160.438 15464.950   1039.585
# GTP            Race2Esport            70         160.438         0 -14425.365
